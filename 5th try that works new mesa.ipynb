# %%
# libraries 
from mesa import Agent, Model
from mesa.discrete_space import CellAgent, FixedAgent
from mesa.datacollection import DataCollector
from mesa.space import MultiGrid

import matplotlib.pyplot as plt
import math
import random

from mesa.discrete_space import OrthogonalVonNeumannGrid

# custom scheduler 

class SimpleScheduler:
    def __init__(self):
        self.agents = []

    def add(self, agent):
        self.agents.append(agent)

    def remove(self, agent):
        if agent in self.agents:
            self.agents.remove(agent)

    def step(self):
        # Loop through a copy to allow safe removal
        for agent in self.agents[:]:
            agent.step()


# merozites 
class Merozoite(Agent):
    def __init__(self, unique_id, model, pos):
        self.unique_id = unique_id
        self.model = model
        self.pos = pos

    def step(self):
        # Move randomly to a neighboring cell (Moore neighborhood)
        neighbors = self.model.grid.get_neighborhood(self.pos, moore=True, include_center=False)
        new_pos = random.choice(neighbors)
        self.model.grid.move_agent(self, new_pos)

        # Try to infect any RBC in the new position
        cell_agents = self.model.grid.get_cell_list_contents([new_pos])
        for agent in cell_agents:
            if isinstance(agent, BloodCell):
                agent.infect()

# defining agents and behavior 
# blood cell 
class BloodCell(Agent):
    def __init__(self,  unique_id, model, pos, genotype="normal", infection_risk=0.5):
        self.model = model
        self.unique_id = unique_id
        self.pos = pos
        self.genotype = genotype
        self.infection_risk = infection_risk
        self.hp = 1
        self.infected = False

    def step(self):
        if self.infected and self.hp <= 0:
            self.resolve()

    def infect(self):
        #Called by a merozoite attempting to infect this RBC
        if not self.infected:
            if random.random() < self.infection_risk:
                self.infected = True
                self.hp = 0  # triggers bursting/removal in next step

    def resolve(self):
        #Handle bursting or dying based on genotype
        if self.genotype == "normal":
            self.burst()
        elif self.genotype == "heterozygous":
            if random.random() < 0.5:
                self.burst()  # 50% chance to burst
            # otherwise dies quietly

        # Remove the RBC in all cases - the infected RBC that burst and the heterozygous ones that sickle 
        self.model.grid.remove_agent(self)
        self.model.schedule.remove(self)

    def burst(self):
        #Produce 2 new merozoites in neighboring empty cells
        neighbors = self.model.grid.get_neighborhood(self.pos, moore=True, include_center=False)
        empty_spaces = [pos for pos in neighbors if self.model.grid.is_cell_empty(pos)]
        # Find all empty neighboring cells where new merozoites can be placed
        for _ in range(2):  # run loop more times if we want more than 2 merozites. 
            if empty_spaces:
                pos = empty_spaces.pop()
                mero = Merozoite(self.model.next_id(), self.model, pos)
                self.model.grid.place_agent(mero, pos)
                self.model.schedule.add(mero)

  #       empty_spaces = [pos for pos in neighbors if self.model.grid.is_cell_empty(pos)]


class MalariaModel1(Model):
    def __init__(self, width=10, height=10, n_rbc=70, n_mero=5, genotype="normal"):
        super().__init__()
        
        self.grid = MultiGrid(width, height, True)
        self.schedule = SimpleScheduler() 
        self.current_id = 0  # initialize counter

        # Create RBCs
        for _ in range(n_rbc): # loops until we get 70 
            x = self.random.randrange(width) # random placement on grid 
            y = self.random.randrange(height)
            rbc = BloodCell(self.next_id(), self, (x, y), genotype=genotype) # unique id, initial position and genotype 
            self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
            self.schedule.add(rbc) #says which agent will take a turn each round

        # Create Merozoites
        for _ in range(n_mero):
            x = self.random.randrange(width)
            y = self.random.randrange(height)
            mero = Merozoite(self.next_id(), self, (x, y))
            self.grid.place_agent(mero, (x, y))
            self.schedule.add(mero)

        # Data collection
        self.datacollector = DataCollector(
            model_reporters={
                "Merozoites": lambda m: sum(isinstance(a, Merozoite) for a in m.schedule.agents),
                "RBCs": lambda m: sum(isinstance(a, BloodCell) for a in m.schedule.agents),
            }
        )

    def next_id(self):
        self.current_id += 1
        return self.current_id
    
    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

# %%
# Create a model instance
model1 = MalariaModel1(width=10, height=10, n_rbc=70, n_mero=5, genotype="normal")

n_steps = 50  # number of time steps to simulate

# Run the simulation
for i in range(n_steps):
    model1.step()  # use the correct instance

# Convert collected data to pandas DataFrame
df = model1.datacollector.get_model_vars_dataframe()

# Plot results
df.plot()
plt.xlabel("Step")
plt.ylabel("Number of agents")
plt.title("Malaria Simulation: Normal RBC")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (5, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (6, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (5, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (8, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (8, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (8, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (8, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (9, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (9, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (3, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (0, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (9, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (8, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (4, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (8, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (6, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (7, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (4, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (5, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (7, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (0, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (2, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (9, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (7, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (7, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (8, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (9, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (5, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (9, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (5, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (3, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (6, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (4, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (9, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (9, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (6, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (8, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (9, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:115: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(rbc, (x, y)) # puts the agent on the grid
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:123: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (4, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mero, (x, y))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:123: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mero, (x, y))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:123: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mero, (x, y))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:123: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (7, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mero, (x, y))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:123: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (9, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mero, (x, y))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (9, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (9, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (8, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (8, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (8, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (7, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (7, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (7, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (3, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (3, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (5, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (0, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (7, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 101 is being placed with
# place_agent() despite already having the position (7, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 102 is being placed with
# place_agent() despite already having the position (7, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 103 is being placed with
# place_agent() despite already having the position (8, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 104 is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 105 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 106 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 107 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 108 is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 109 is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 110 is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 111 is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 112 is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 113 is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 114 is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 115 is being placed with
# place_agent() despite already having the position (7, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 116 is being placed with
# place_agent() despite already having the position (5, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 117 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 118 is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 119 is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 120 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 121 is being placed with
# place_agent() despite already having the position (3, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 122 is being placed with
# place_agent() despite already having the position (3, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 123 is being placed with
# place_agent() despite already having the position (8, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 124 is being placed with
# place_agent() despite already having the position (9, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 125 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 126 is being placed with
# place_agent() despite already having the position (7, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 127 is being placed with
# place_agent() despite already having the position (7, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 128 is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 129 is being placed with
# place_agent() despite already having the position (5, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 130 is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 131 is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 132 is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 133 is being placed with
# place_agent() despite already having the position (6, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 134 is being placed with
# place_agent() despite already having the position (4, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 135 is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 136 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 137 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 138 is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 139 is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 140 is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 141 is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 142 is being placed with
# place_agent() despite already having the position (3, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 143 is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 144 is being placed with
# place_agent() despite already having the position (8, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 145 is being placed with
# place_agent() despite already having the position (5, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 146 is being placed with
# place_agent() despite already having the position (5, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 147 is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 148 is being placed with
# place_agent() despite already having the position (9, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 149 is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 150 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 151 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 152 is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 153 is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 154 is being placed with
# place_agent() despite already having the position (6, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 155 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 156 is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 157 is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 158 is being placed with
# place_agent() despite already having the position (6, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 159 is being placed with
# place_agent() despite already having the position (4, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 160 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 161 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 162 is being placed with
# place_agent() despite already having the position (9, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 163 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 164 is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 165 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 166 is being placed with
# place_agent() despite already having the position (9, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 167 is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 168 is being placed with
# place_agent() despite already having the position (8, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 169 is being placed with
# place_agent() despite already having the position (8, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 170 is being placed with
# place_agent() despite already having the position (8, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 171 is being placed with
# place_agent() despite already having the position (8, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 172 is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 173 is being placed with
# place_agent() despite already having the position (6, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 174 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 175 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 176 is being placed with
# place_agent() despite already having the position (9, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 177 is being placed with
# place_agent() despite already having the position (7, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 178 is being placed with
# place_agent() despite already having the position (9, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 179 is being placed with
# place_agent() despite already having the position (4, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 180 is being placed with
# place_agent() despite already having the position (4, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 181 is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 182 is being placed with
# place_agent() despite already having the position (7, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 183 is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 184 is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 185 is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 186 is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 187 is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 188 is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 189 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 190 is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15692\4267916340.py:96: UserWarning: Agent 191 is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(mero, pos)

# %%
# delay in merozite release, 
# simulate 2 simulations one with 

# simulate liver like env , 10 minutes to infect
